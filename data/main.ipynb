# %%
pip install spacy
spacy.cli.download("en_core_web_sm")
# Out:
#   Cell In[37], line 1
#     pip install spacy
#         ^
# SyntaxError: invalid syntax

# %%
#python -m spacy download en_core_web_sm
# Out:
#   Cell In[12], line 1
#     install python -m spacy download en_core_web_sm
#             ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
import matplotlib.pyplot as plt
import spacy

# %%
data = pd.read_excel('processed_medication_data.xlsx')
route_counts = data['Route of administration'].value_counts()
data.head(100)
# Out:
#                                     Product name  \
# 0                                            Aas
# 1                Abacavir + Lamivudina Atirdrane
# 2                Abacavir + Lamivudina Aurovitas
# 3                   Abacavir + Lamivudina Farmoz
# 4                    Abacavir + Lamivudina Mylan
# ..                                           ...
# 95             Ácido Acetilsalicílico Ratiopharm
# 96                 Ácido Acetilsalicílico Tolife
# 97            Ácido Alendrónico + Colecalciferol
# 98     Ácido Alendrónico + Colecalciferol Aristo
# 99  Ácido Alendrónico + Colecalciferol Aurobindo
#
#                                    Active substance\n Route of administration  \
# 0                                Acetylsalicylic Acid                Oral Use
# 1                                Abacavir, Lamivudine                Oral Use
# 2                                Abacavir, Lamivudine                Oral Use
# ...

# %%
# Count the total number of rows
total_rows = data.shape[0]

# Print the result
print("Total number of rows:", total_rows)
# Out:
# Total number of rows: 8057

# %%
unique_routes_count = data['Route of administration'].nunique()

# Display the count
print("Number of different routes of administration:", unique_routes_count)
# Out:
# Number of different routes of administration: 149

# %%
# Count the occurrences of each route of administration
route_counts = data['Route of administration'].value_counts()

route_counts = route_counts.head(15)

# Create a bar graph
plt.figure(figsize=(15, 7))
route_counts.plot(kind='bar')
plt.xlabel('Route of Administration')
plt.ylabel('Count')
plt.title('Medicinal Drugs by Route of Administration')
plt.xticks(rotation=90)

# Show the graph
plt.tight_layout()
plt.show()

# %%
#40 substâncias ativas mais comuns

substance_counts = data['Active substance\n'].value_counts()

# Select the top 40 most common substances
top_40_substances = substance_counts.head(40)

# Create a bar graph for the top 40 substances
plt.figure(figsize=(12, 6))  # Adjust the figure size
ax = top_40_substances.plot(kind='bar')
ax.set_xlabel('Active substance\n')
ax.set_ylabel('Count')
ax.set_title('Top 40 Medicinal Drugs by Active substance')
ax.tick_params(axis='x', rotation=90)

# Show the graph
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Gráficos da metadata recolhida

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming you have a pandas DataFrame named 'df' with the data
# Replace 'df' with your DataFrame name

# Group the data by the "Marketing authorisation holder" column
holder_counts = data['Marketing authorisation holder'].value_counts().head(25)

# Plot a pie chart
plt.figure(figsize=(10, 10))
plt.pie(holder_counts, labels=holder_counts.index, autopct='%1.1f%%', startangle=140)
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

# Add a title
plt.title("Top 25 Distribution Marketing Authorisation Holder")

# Display the pie chart
plt.show()

# %%
column_name = 'Genérico:'

# Get value counts for the specified column
value_counts = data[column_name].value_counts()

# Select the top N values (for example, top 10)
top_N = 10
top_values = value_counts.head(top_N)

# Create a bar chart
plt.figure(figsize=(12, 6))
top_values.plot(kind='bar')
column_name = 'Genérico'
plt.title(f'Values in Column {column_name}')
plt.xlabel(column_name)
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %%
# Specify the column name
column_name = 'Duração do Tratamento:'

# Get value counts for the specified column and select the top 10
top_10_values = data[column_name].value_counts().head(10)

# Create a bar chart for the top 10 values
plt.figure(figsize=(12, 6))
top_10_values.plot(kind='bar')
column_name = 'Duração do Tratamento'
plt.title(f'Values in Column {column_name}')
plt.xlabel(column_name)
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()
